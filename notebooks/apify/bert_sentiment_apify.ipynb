# %%
import pandas as pd
import emoji
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# %%
df = pd.read_csv('../../data/apify/comments_apify_processed.csv')
df.head(10)
# Out:
#                      cmtDate            postId  \
# 0  2025-06-02 07:05:22+00:00  1147436614095615
# 1  2025-06-02 07:04:14+00:00  1147436614095615
# 2  2025-06-02 06:33:15+00:00  1147436614095615
# 3  2025-06-01 10:42:34+00:00  1146548730851070
# 4  2025-06-01 09:24:03+00:00  1146548730851070
# 5  2025-06-01 03:43:02+00:00  1146504504188826
# 6  2025-06-01 02:29:56+00:00  1146504504188826
# 7  2025-06-01 01:04:13+00:00  1146504504188826
# 8  2025-06-01 02:54:30+00:00  1146504504188826
# 9  2025-06-01 01:46:20+00:00  1146504504188826
#
#                                               userId  \
# 0  pfbid036432FUUhBiAzqFUkjSn8ZR3JqpSz9qfJyZ9qFwA...
# 1                                    100082365036655
# 2                                    100010438388165
# 3  pfbid036432FUUhBiAzqFUkjSn8ZR3JqpSz9qfJyZ9qFwA...
# 4                                    100082365036655
# 5  pfbid02vrerdeMR2eCGuRDBSkngtWyL5eoMRZkgLn11m5C...
# 6                                    100005658369921
# 7  pfbid0Y3aDzJzsRfJtZbJCigEeGGAD7LENS4DHTizR1K2p...
# 8  pfbid0BKiWDx96iWSYTerMP7zS7LbciGFJeFoKqbUuCskw...
# 9  pfbid02TWA7CFgJmJbEgbZCHsprRLCDsCjqMKL53KRf6f6...
#
#                                              cmtText  cmtLikes
# 0                                      Rất tuyệt vời         0
# 1                                         Mua laptop         0
# 2                                              hello         0
# 3                                      Rất tuyệt vời         0
# 4                                   Mua 2 cái laptop         0
# 5  "Không chỉ... Mà còn..."\nGiờ giáo viên tiếng ...        32
# 6  Laptop là laptop, chừng nào bán cặp sách thì n...        39
# 7                 Content của thế hệ cợt nhả đây sao        39
# 8                     Content nhạt hơn nước cất 🤦‍♀️        22
# 9                       Làm content chán quá shop ơi        23

# %%
def remove_emoji(text):
    return emoji.replace_emoji(str(text), replace='')

df['cmtText_clean'] = df['cmtText'].apply(remove_emoji)
df[['cmtText', 'cmtText_clean']].head(10)
# Out:
#                                              cmtText  \
# 0                                      Rất tuyệt vời
# 1                                         Mua laptop
# 2                                              hello
# 3                                      Rất tuyệt vời
# 4                                   Mua 2 cái laptop
# 5  "Không chỉ... Mà còn..."\nGiờ giáo viên tiếng ...
# 6  Laptop là laptop, chừng nào bán cặp sách thì n...
# 7                 Content của thế hệ cợt nhả đây sao
# 8                     Content nhạt hơn nước cất 🤦‍♀️
# 9                       Làm content chán quá shop ơi
#
#                                        cmtText_clean
# 0                                      Rất tuyệt vời
# 1                                         Mua laptop
# 2                                              hello
# 3                                      Rất tuyệt vời
# 4                                   Mua 2 cái laptop
# 5  "Không chỉ... Mà còn..."\nGiờ giáo viên tiếng ...
# 6  Laptop là laptop, chừng nào bán cặp sách thì n...
# 7                 Content của thế hệ cợt nhả đây sao
# 8                         Content nhạt hơn nước cất
# 9                       Làm content chán quá shop ơi

# %%
model_name = "hieudinhpro/BERT_Sentiment_Vietnamese"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()
# Out:
# RobertaForSequenceClassification(
#   (roberta): RobertaModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(64001, 768, padding_idx=1)
#       (position_embeddings): Embedding(258, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): RobertaEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (classifier): RobertaClassificationHead(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (out_proj): Linear(in_features=768, out_features=3, bias=True)
#   )
# )

# %%
labels = ['negative', 'neutral', 'positive']

class CommentDataset(Dataset):
    def __init__(self, texts):
        self.texts = texts

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        return self.texts[idx]

def collate_batch(batch_texts):
    return tokenizer(batch_texts, return_tensors="pt", truncation=True, padding=True)

# %%
texts = df['cmtText_clean'].fillna("").tolist()
dataset = CommentDataset(texts)
dataloader = DataLoader(dataset, batch_size=16, collate_fn=collate_batch)

all_preds = []

with torch.no_grad():
    for batch in dataloader:
        batch = {k: v.to(device) for k, v in batch.items()}
        outputs = model(**batch)
        probs = F.softmax(outputs.logits, dim=-1)
        preds = torch.argmax(probs, dim=-1)
        all_preds.extend(preds.cpu().tolist())

# %%
df['sentiment'] = [labels[p] for p in all_preds]
df[['cmtText_clean', 'sentiment']]
# Out:
#                              cmtText_clean sentiment
# 0                            Rất tuyệt vời  positive
# 1                               Mua laptop   neutral
# 2                                    hello   neutral
# 3                            Rất tuyệt vời  positive
# 4                         Mua 2 cái laptop   neutral
# ..                                     ...       ...
# 398                               Trung Lê  positive
# 399                          Minh Thuỷ =))   neutral
# 400  Không bán thì thôi, thiếu gì chỗ mua   negative
# 401                      Tuyết Ngọc là sao   neutral
# 402            Nguyễn Vương Kim Đào hahaaa  positive
#
# [403 rows x 2 columns]

# %%
sentiment_counts = df['sentiment'].value_counts()
sentiment_percent = df['sentiment'].value_counts(normalize=True) * 100

result = pd.DataFrame({
    'Count': sentiment_counts,
    'Percentage (%)': sentiment_percent.round(2)
})

result
# Out:
#            Count  Percentage (%)
# sentiment
# negative     214           53.10
# neutral      155           38.46
# positive      34            8.44

# %%
positive_df = df[df['sentiment'] == 'positive']
positive_df
# Out:
#                        cmtDate            postId  \
# 0    2025-06-02 07:05:22+00:00  1147436614095615
# 3    2025-06-01 10:42:34+00:00  1146548730851070
# 47   2025-06-01 08:35:59+00:00  1146529790852964
# 57   2025-06-01 02:08:26+00:00  1146504504188826
# 60   2025-06-02 04:26:10+00:00  1147413360764607
# 76   2025-06-01 02:45:13+00:00  1146504504188826
# 89   2025-05-30 15:53:43+00:00  1145328240973119
# 91   2025-05-31 04:47:58+00:00  1145328240973119
# 150  2025-06-01 03:13:23+00:00  1146504504188826
# 165  2025-05-30 13:26:56+00:00  1145328240973119
# 167  2025-05-30 13:21:56+00:00  1145328240973119
# 176  2025-06-01 08:27:47+00:00  1146504504188826
# 184  2025-06-01 02:31:20+00:00  1146504504188826
# 213  2025-06-01 02:36:15+00:00  1146504504188826
# 235  2025-06-01 01:22:49+00:00  1146504504188826
# 250  2025-06-01 09:04:50+00:00  1146504504188826
# 251  2025-06-01 02:48:52+00:00  1146504504188826
# 270  2025-05-30 11:19:51+00:00  1145328240973119
# 281  2025-05-30 11:09:15+00:00  1145328240973119
# 282  2025-05-30 11:08:43+00:00  1145328240973119
# 286  2025-05-30 10:59:37+00:00  1145328240973119
# 310  2025-05-30 12:46:23+00:00  1145328240973119
# 334  2025-05-30 10:55:15+00:00  1145328240973119
# 339  2025-05-30 15:42:15+00:00  1145328240973119
# 355  2025-05-31 01:20:17+00:00  1145328240973119
# 364  2025-05-31 11:13:01+00:00  1145328240973119
# 370  2025-05-31 09:51:07+00:00  1145328240973119
# 381  2025-05-30 11:10:04+00:00  1145328240973119
# 387  2025-05-31 00:59:39+00:00  1145328240973119
# 57                    Tặng office trọn đời hay sao ạ 😆         2
# 60                      Content này còn được này add:)         4
# 76                              Office vĩnh viễn hả ta         0
# 89                   Ai duyệt camp này được cũng hay 🥲         0
# 91                                           Continued         0
# 150                                           Cười v 🤣         4
# 165                         Chak ban may tinh sach tay         0
# 167                                      Nói linh tinh         0
# 176      Content đỉnh nóc nhỉ Ngọc Hà Phan Mạnh Tiến 🤣         0
# 184                 Tâm Thu DAnhh Caoo coi content nè.         0
# 213                   Content này phản dame nha- chê á         1
# 235                                   Phạm Lo bồi hoàn         1
# 250                                   Đồng Phương Thảo         0
# 251                    Huỳnh Khánh Linh Lê Thị Hoài Ni         1
# 270                                             Bỏ hả￼         0
# 281       chắc số laptop 30-31 tháng 05 này tốt lắm nè         2
# 282                                             Tặng y         0
# 286                                     Tin chuẩn k ad         0
# 310           Để qua fpt shop. Thanks ad thông tin nha         0
# 334                                  Sửa nhanh zị shop         1
# 339  Thegioididong mãi đỉnh. 😃 Bán giá tốt mà tư vấ...         0
# 355                             Ok qua chỗ nào bán mua         0
# 364                                     Content mạnh v         0
# 370  Nguyễn Tính đọc cmt… tôi có thể cười đến cuối đời         1
# 381                                Hết ý tưởng r à ad🤣         0
# 387                                        Vinh Nguyễn         0
# 394                                           Thu Thảo         0
# 396                                       Vũ Linh Tran         0
# 397                                          Ngọc Phạm         1
# 398                                           Trung Lê         0
# 402                        Nguyễn Vương Kim Đào hahaaa         0
#
#                                          cmtText_clean sentiment
# 0                                        Rất tuyệt vời  positive
# 3                                        Rất tuyệt vời  positive
# 47                                       Rất tuyệt vời  positive
# 57                     Tặng office trọn đời hay sao ạ   positive
# 60                      Content này còn được này add:)  positive
# 76                              Office vĩnh viễn hả ta  positive
# 89                    Ai duyệt camp này được cũng hay   positive
# 91                                           Continued  positive
# 150                                            Cười v   positive
# 165                         Chak ban may tinh sach tay  positive
# 167                                      Nói linh tinh  positive
# 176       Content đỉnh nóc nhỉ Ngọc Hà Phan Mạnh Tiến   positive
# 184                 Tâm Thu DAnhh Caoo coi content nè.  positive
# 213                   Content này phản dame nha- chê á  positive
# 235                                   Phạm Lo bồi hoàn  positive
# 250                                   Đồng Phương Thảo  positive
# 251                    Huỳnh Khánh Linh Lê Thị Hoài Ni  positive
# 270                                             Bỏ hả￼  positive
# 281       chắc số laptop 30-31 tháng 05 này tốt lắm nè  positive
# 282                                             Tặng y  positive
# 286                                     Tin chuẩn k ad  positive
# 310           Để qua fpt shop. Thanks ad thông tin nha  positive
# 334                                  Sửa nhanh zị shop  positive
# 339  Thegioididong mãi đỉnh.  Bán giá tốt mà tư vấn...  positive
# 355                             Ok qua chỗ nào bán mua  positive
# 364                                     Content mạnh v  positive
# 370  Nguyễn Tính đọc cmt… tôi có thể cười đến cuối đời  positive
# 381                                 Hết ý tưởng r à ad  positive
# 387                                        Vinh Nguyễn  positive
# 394                                           Thu Thảo  positive
# 396                                       Vũ Linh Tran  positive
# 397                                          Ngọc Phạm  positive
# 398                                           Trung Lê  positive
# 402                        Nguyễn Vương Kim Đào hahaaa  positive

# %%
df.to_csv('../../data/apify/comments_apify_processed_with_sentiment.csv', index=False)
